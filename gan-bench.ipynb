# %%
import gan_mnist as g
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2
# Imported successfully!

# %%
# define the Gan 
gan = g.Gan()

# loading Mnist dataset
gan.load_dataset()

# verify dataset shapes
print(f'Training shape:  x = {gan.train_x_shape}; y = {gan.train_y_shape}')
print(f'Test shape: x = {gan.test_x_shape}; y = {gan.test_y_shape}')

gan.show_data(gan.train_x)
# Out:
# Training shape:  x = (60000, 28, 28); y = (60000,)
# Test shape: x = (10000, 28, 28); y = (10000,)

# %%
# define discriminator
discriminator = gan.discriminator()

# train discriminator
#discriminator = gan.train_discriminator()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 28, 28, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 7, 7, 64)          256
# ...

# %%
generator = gan.generator()

# fake samples
x_fake, y_fake = gan.generate_fake_samples_generator(25)

'''plot the generated samples. As the generator is not trained the generated images
are completely random pixels values'''

gan.show_data(x_fake)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 6272)              633472
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 128)       262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 28, 28, 128)       0
# ...

# %%
gan_model = gan.gan(discriminator, generator)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-40963bbd55d9> in <module>
# ----> 1 gan_model = gan.gan(discriminator, generator)
#
# c:\AI\Projeto CV\gan\gan_mnist.py in gan(self, d_model, g_model)
#     222     def gan(self, d_model, g_model):
#     223         # make the weights in the discriminator not trainable
# --> 224         d_model.trainable = False
#     225         # connect both models
#     226         model = Sequential()
#
# AttributeError: 'NoneType' object has no attribute 'trainable'
